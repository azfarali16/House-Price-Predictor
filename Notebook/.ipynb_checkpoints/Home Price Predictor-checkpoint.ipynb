# %% [markdown]
# # House Price Predictor Model

# %% [markdown]
# ## Objective:
# Build a House Price Prediciton Model For Houses in Karachi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'Entities.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0  property_id  location_id  \
# 0           0       237062         3325
# 1           1       346905         3236
# 2           2       386513          764
# 3           3       656161          340
# 4           4       841645         3226
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  16500000
# 3  https://www.zameen.com/Property/islamabad_bani...         House  43500000
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   7000000
#
#       location       city      province_name   latitude  longitude  baths  \
# 0         G-10  Islamabad  Islamabad Capital  33.679890  73.012640      2
# 1         E-11  Islamabad  Islamabad Capital  33.700993  72.971492      3
# 2         G-15  Islamabad  Islamabad Capital  33.631486  72.926559      6
# 3    Bani Gala  Islamabad  Islamabad Capital  33.707573  73.151199      4
# 4  DHA Defence  Islamabad  Islamabad Capital  33.492591  73.301339      3
#
#     purpose  bedrooms date_added         agency  \
# 0  For Sale         2   2/4/2019            NaN
# 1  For Sale         3   5/4/2019            NaN
# 2  For Sale         5  7/17/2019            NaN
# 3  For Sale         4   4/5/2019            NaN
# 4  For Sale         3  7/10/2019  Easy Property
#
#                                           agent  Total_Area
# 0                                           NaN    1089.004
# 1                                           NaN   15246.056
# 2                                           NaN    2178.008
# 3                                           NaN   10890.000
# 4  Muhammad Junaid Ceo Muhammad Shahid Director    2178.008

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'property_id', 'location_id', 'page_url', 'property_type',
#        'price', 'location', 'city', 'province_name', 'latitude', 'longitude',
#        'baths', 'purpose', 'bedrooms', 'date_added', 'agency', 'agent',
#        'Total_Area'],
#       dtype='object')

# %%
cols_to_keep = [ 'property_type',
       'price', 'location', 'city', 'province_name',
       'baths', 'purpose', 'bedrooms', 
       'Total_Area']

df = df[cols_to_keep]
df.head()
# Out:
#   property_type     price     location       city      province_name  baths  \
# 0          Flat  10000000         G-10  Islamabad  Islamabad Capital      2
# 1          Flat   6900000         E-11  Islamabad  Islamabad Capital      3
# 2         House  16500000         G-15  Islamabad  Islamabad Capital      6
# 3         House  43500000    Bani Gala  Islamabad  Islamabad Capital      4
# 4         House   7000000  DHA Defence  Islamabad  Islamabad Capital      3
#
#     purpose  bedrooms  Total_Area
# 0  For Sale         2    1089.004
# 1  For Sale         3   15246.056
# 2  For Sale         5    2178.008
# 3  For Sale         4   10890.000
# 4  For Sale         3    2178.008

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168446 entries, 0 to 168445
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_type  168446 non-null  object
#  1   price          168446 non-null  int64
#  2   location       168446 non-null  object
#  3   city           168446 non-null  object
#  4   province_name  168446 non-null  object
#  5   baths          168446 non-null  int64
#  6   purpose        168446 non-null  object
#  7   bedrooms       168446 non-null  int64
#  8   Total_Area     168446 non-null  float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 11.6+ MB

# %%
df.province_name.unique()
# Out:
# array(['Islamabad Capital', 'Punjab', 'Sindh'], dtype=object)

# %%
df.city.unique()
# Out:
# array(['Islamabad', 'Lahore', 'Faisalabad', 'Rawalpindi', 'Karachi'],
#       dtype=object)

# %%
# since we have to make it for Karachi only. Subsetting df

df = df[df['city'] == 'Karachi']
df.head()
# Out:
#     property_type      price           location     city province_name  baths  \
# 156         House  450000000              Cantt  Karachi         Sindh      7
# 157         House   35000000  Gulistan-e-Jauhar  Karachi         Sindh      8
# 158          Flat   21000000        DHA Defence  Karachi         Sindh      3
# 159         House    6500000              Malir  Karachi         Sindh      1
# 160         House   13000000         Gadap Town  Karachi         Sindh      4
#
#       purpose  bedrooms  Total_Area
# 156  For Sale         6   21780.000
# 157  For Sale         6    4356.016
# 158  For Sale         3   24230.339
# 159  For Sale         2    8712.032
# 160  For Sale         4   26136.096

# %%
df.property_type.unique()
# Out:
# array(['House', 'Flat', 'Room', 'Lower Portion', 'Upper Portion',
#        'Penthouse', 'Farm House'], dtype=object)

# %%
# keeping the model genereic. removin penthhouse and farm house
property_to_rem = ['Penthouse','Farm House','Room']
bool_mask = df['property_type'].isin(property_to_rem)
df = df[~(bool_mask)]
df.property_type.unique()
# Out:
# array(['House', 'Flat', 'Lower Portion', 'Upper Portion'], dtype=object)

# %%
# removing extra col like city and province_name since like we are only targeting karachi
cols_to_rem = ['city','province_name']
df.drop(columns=cols_to_rem,inplace = True)

# %% [markdown]
# data cleaning

# %%
df1 = df.copy()

# %%
df1.isna().sum()
# Out:
# property_type    0
# price            0
# location         0
# baths            0
# purpose          0
# bedrooms         0
# Total_Area       0
# dtype: int64

# %%
df1.rename(columns={'Total_Area':'area'},inplace=True)

# %%
df1 = df1[['property_type',  'location', 'baths', 'purpose', 'bedrooms',
       'area','price']]

# %%
df2 = df1.copy()
df2 = df2[df2['purpose']=='For Sale']
df2.drop(columns=['purpose'],inplace=True)
df2.head(1)
# Out:
#     property_type location  baths  bedrooms     area      price
# 156         House    Cantt      7         6  21780.0  450000000

# %%
df2['price'] = df2['price']/1e6 #in 10THlakhs unit
df2.head(1)
# Out:
#     property_type location  baths  bedrooms     area  price
# 156         House    Cantt      7         6  21780.0  450.0

# %% [markdown]
# ### Removing Outliers

# %%
df2['baths'].describe() ,  df2.bedrooms.describe()
# Out:
# (count    46353.000000
#  mean         2.619507
#  std          1.960773
#  min          0.000000
#  25%          2.000000
#  50%          3.000000
#  75%          3.000000
#  max         13.000000
#  Name: baths, dtype: float64,
#  count    46353.000000
#  mean         3.073997
#  std          1.809227
#  min          0.000000
#  25%          2.000000
#  50%          3.000000
#  75%          4.000000
#  max         16.000000
#  Name: bedrooms, dtype: float64)

# %%
df2 = df2[~((df2['baths']==0) | (df2['bedrooms'] == 0))]

# %%
df3 = df2.copy()

df3[df3['baths'] > df3['bedrooms']+1].head(), df2.shape
# Out:
# (    property_type              location  baths  bedrooms       area  price
#  157         House     Gulistan-e-Jauhar      8         6   4356.016   35.0
#  351         House  Gulshan-e-Iqbal Town      6         4  16335.000  250.0
#  517          Flat               Clifton      5         3  28041.853   48.0
#  518          Flat               Clifton      5         3  28041.853   50.0
#  704          Flat           Bath Island      5         3  28041.853   50.0,
#  (36089, 6))

# %%
df3 = df3[~(df3['baths'] > df3['bedrooms']+1)]

df3 = df3[df3['bedrooms'] <= df3['baths'] + 1]

print(df3.head())
df3.shape
# Out:
#     property_type     location  baths  bedrooms       area  price
# 156         House        Cantt      7         6  21780.000  450.0
# 158          Flat  DHA Defence      3         3  24230.339   21.0
# 159         House        Malir      1         2   8712.032    6.5
# 160         House   Gadap Town      4         4  26136.096   13.0
# 161         House  DHA Defence      4         4   1089.004   32.0
# (34035, 6)

# %%
df3['area'].describe()
# Out:
# count     34035.000000
# mean      12455.505313
# std       16234.945037
# min           0.000000
# 25%        2722.510000
# 50%       10890.000000
# 75%       15246.056000
# max      952875.000000
# Name: area, dtype: float64

# %%
sns.kdeplot(df3[df3['area']<df3['area'].quantile(0.75)]['area'])
# Out:
# <Axes: xlabel='area', ylabel='Density'>

# %%
df4 = df3.copy()
df4 = df4[(df4['area'] >= 500) & (df4['area'] <= df4['area'].quantile(0.75))]
df4 = df4[df4['area']<10000]

sns.kdeplot(df4['area'])
# Out:
# <Axes: xlabel='area', ylabel='Density'>

# %%
df4['price_per_sqft'] = df4['price']*1e6/df4['area']
df4.head()
# Out:
#     property_type                  location  baths  bedrooms      area  price  \
# 159         House                     Malir      1         2  8712.032    6.5
# 161         House               DHA Defence      4         4  1089.004   32.0
# 164         House               DHA Defence      6         6  5445.000  110.0
# 175          Flat  Abul Hassan Isphani Road      2         2  8712.032    4.1
# 180         House                     Malir      5         5  3811.514   59.5
#
#      price_per_sqft
# 159      746.094597
# 161    29384.648725
# 164    20202.020202
# 175      470.613515
# 180    15610.594635

# %%
q1 = df4['price_per_sqft'].quantile(0.25)
q3 = df4['price_per_sqft'].quantile(0.75)

iqr = q3-q1

lb = q1 - 1.5*(iqr)
ub = q3 + 1.5*iqr

lb,ub
# Out:
# (-12220.55992114229, 23126.584642313697)

# %%
df4['price'] = df4['price']*1e1

# %%
df4 = df4[~(df4['price_per_sqft']/df4['bedrooms']<300)]

# %%
df5= df4.copy()
df5.drop(columns=['price_per_sqft'],inplace=True)

# %%
df5.columns
# Out:
# Index(['property_type', 'location', 'baths', 'bedrooms', 'area', 'price'], dtype='object')

# %%
df5.head()
# Out:
#     property_type     location  baths  bedrooms      area   price
# 159         House        Malir      1         2  8712.032    65.0
# 161         House  DHA Defence      4         4  1089.004   320.0
# 164         House  DHA Defence      6         6  5445.000  1100.0
# 180         House        Malir      5         5  3811.514   595.0
# 181         House        Malir      5         5  5445.000   715.0

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Define feature matrix X and target vector y
X = df5.drop(columns=['price'])  # Drop the 'price' column to get features
y = df5['price']  # Target variable



X = pd.get_dummies(X, columns=['property_type', 'location'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_regressor.fit(X_train, y_train)

# Make predictions
y_pred = rf_regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print results
print(f'Mean Squared Error: {mse:.2f}')
print(f'R^2 Score: {r2:.2f}')
# Out:
# Mean Squared Error: 9586.86
# R^2 Score: 0.91

# %%
X
# Out:
#         baths  bedrooms      area  property_type_Flat  property_type_House  \
# 159         1         2  8712.032               False                 True
# 161         4         4  1089.004               False                 True
# 164         6         6  5445.000               False                 True
# 180         5         5  3811.514               False                 True
# 181         5         5  5445.000               False                 True
# ...       ...       ...       ...                 ...                  ...
# 168435      3         3  2178.008                True                False
# 168436      4         3  2178.008               False                 True
# 168437      4         3  1361.255               False                 True
# 168438      3         3  2178.008               False                 True
# 168439      4         4  3811.514               False                 True
#
#         property_type_Lower Portion  property_type_Upper Portion  \
# 159                           False                        False
# 161                           False                        False
# 164                           False                        False
# 180                           False                        False
# 181                           False                        False
# ...                             ...                          ...
# 168435                        False                        False
# 168436                        False                        False
# 168437                        False                        False
# 168438                        False                        False
# 168439                        False                        False
#
#         location_APP Employees Co-operative Housing Society  \
# 159                                                 False
# 161                                                 False
# 164                                                 False
# 180                                                 False
# 181                                                 False
# ...                                                   ...
# 168435                                              False
# 168436                                              False
# 168437                                              False
# 168438                                              False
# 168439                                              False
#
#         location_ASF Tower  location_Abdullah Ahmed Road  ...  \
# 159                  False                         False  ...
# 161                  False                         False  ...
# 164                  False                         False  ...
# 180                  False                         False  ...
# 181                  False                         False  ...
# ...                    ...                           ...  ...
# 168435               False                         False  ...
# 168436               False                         False  ...
# 168437               False                         False  ...
# 168438               False                         False  ...
# 168439               False                         False  ...
#
#         location_Siraj-ud-Daula Road  location_Stadium Road  \
# 159                            False                  False
# 161                            False                  False
# 164                            False                  False
# 180                            False                  False
# 181                            False                  False
# ...                              ...                    ...
# 168435                         False                  False
# 168436                         False                  False
# 168437                         False                  False
# 168438                         False                  False
# 168439                         False                  False
#
#         location_Suparco Road  location_Super Highway  \
# 159                     False                   False
# 161                     False                   False
# 164                     False                   False
# 180                     False                   False
# 181                     False                   False
# ...                       ...                     ...
# 168435                  False                   False
# 168436                  False                   False
# 168437                  False                   False
# 168438                  False                   False
# 168439                  False                   False
#
#         location_Surti Muslim Co-Operative Housing Society  \
# 159                                                 False
# 161                                                 False
# 164                                                 False
# 180                                                 False
# 181                                                 False
# ...                                                   ...
# 168435                                              False
# 168436                                              False
# 168437                                              False
# 168438                                              False
# 168439                                              False
#
#         location_Tariq Road  location_Teachers Society  \
# 159                   False                      False
# 161                   False                      False
# 164                   False                      False
# 180                   False                      False
# 181                   False                      False
# ...                     ...                        ...
# 168435                False                      False
# 168436                False                      False
# 168437                False                      False
# 168438                False                      False
# 168439                False                      False
#
#         location_Tipu Sultan Road  location_University Road  location_Zamzama
# 159                         False                     False             False
# 161                         False                     False             False
# 164                         False                     False             False
# 180                         False                     False             False
# 181                         False                     False             False
# ...                           ...                       ...               ...
# 168435                      False                     False             False
# 168436                      False                     False             False
# 168437                      False                     False             False
# 168438                      False                     False             False
# 168439                      False                     False             False
#
# [13544 rows x 143 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error, r2_score

# Define feature matrix X and target vector y
X = df5.drop(columns=['price'])  # Drop the 'price' column to get features
y = df5['price']  # Target variable

# Create a ColumnTransformer to handle scaling and encoding
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), X.select_dtypes(include=['int64', 'float64']).columns),  # Scale numeric columns
        ('cat', OneHotEncoder(), ['property_type', 'location'])  # One-hot encode categorical columns
    ]
)

# Apply the transformations to X
X_transformed = preprocessor.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.3, random_state=42)

# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_regressor.fit(X_train, y_train)

# Make predictions
y_pred = rf_regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print results
print(f'Mean Squared Error: {mse:.2f}')
print(f'R^2 Score: {r2:.2f}')
# Out:
# Mean Squared Error: 9568.76
# R^2 Score: 0.91

# %%
X_train
# Out:
#         baths  bedrooms      area  property_type_Flat  property_type_House  \
# 23956       8         7  5445.000               False                 True
# 150787      3         3  1361.255               False                 True
# 154511      3         3  2178.008               False                 True
# 40451       4         3  2178.008               False                 True
# 49341       8         8  2178.008               False                 True
# ...       ...       ...       ...                 ...                  ...
# 68202       2         2  1089.004               False                False
# 167116      3         3  2722.510                True                False
# 70402       6         6  3267.012               False                 True
# 12942       2         2  9801.036                True                False
# 92143       5         5  5445.000               False                 True
#
#         property_type_Lower Portion  property_type_Upper Portion  \
# 23956                         False                        False
# 150787                        False                        False
# 154511                        False                        False
# 40451                         False                        False
# 49341                         False                        False
# ...                             ...                          ...
# 68202                         False                         True
# 167116                        False                        False
# 70402                         False                        False
# 12942                         False                        False
# 92143                         False                        False
#
#         location_APP Employees Co-operative Housing Society  \
# 23956                                               False
# 150787                                              False
# 154511                                              False
# 40451                                               False
# 49341                                               False
# ...                                                   ...
# 68202                                               False
# 167116                                              False
# 70402                                               False
# 12942                                               False
# 92143                                               False
#
#         location_ASF Tower  location_Abdullah Ahmed Road  ...  \
# 23956                False                         False  ...
# 150787               False                         False  ...
# 154511               False                         False  ...
# 40451                False                         False  ...
# 49341                False                         False  ...
# ...                    ...                           ...  ...
# 68202                False                         False  ...
# 167116               False                         False  ...
# 70402                False                         False  ...
# 12942                False                         False  ...
# 92143                False                         False  ...
#
#         location_Siraj-ud-Daula Road  location_Stadium Road  \
# 23956                          False                  False
# 150787                         False                  False
# 154511                         False                  False
# 40451                          False                  False
# 49341                          False                  False
# ...                              ...                    ...
# 68202                          False                  False
# 167116                         False                  False
# 70402                          False                  False
# 12942                          False                  False
# 92143                          False                  False
#
#         location_Suparco Road  location_Super Highway  \
# 23956                   False                   False
# 150787                  False                   False
# 154511                  False                   False
# 40451                   False                   False
# 49341                   False                   False
# ...                       ...                     ...
# 68202                   False                   False
# 167116                  False                   False
# 70402                   False                   False
# 12942                   False                   False
# 92143                   False                   False
#
#         location_Surti Muslim Co-Operative Housing Society  \
# 23956                                               False
# 150787                                              False
# 154511                                              False
# 40451                                               False
# 49341                                               False
# ...                                                   ...
# 68202                                               False
# 167116                                              False
# 70402                                               False
# 12942                                               False
# 92143                                               False
#
#         location_Tariq Road  location_Teachers Society  \
# 23956                 False                      False
# 150787                False                      False
# 154511                False                      False
# 40451                 False                      False
# 49341                 False                      False
# ...                     ...                        ...
# 68202                 False                      False
# 167116                False                      False
# 70402                 False                      False
# 12942                 False                      False
# 92143                 False                      False
#
#         location_Tipu Sultan Road  location_University Road  location_Zamzama
# 23956                       False                     False             False
# 150787                      False                     False             False
# 154511                      False                     False             False
# 40451                       False                     False             False
# 49341                       False                     False             False
# ...                           ...                       ...               ...
# 68202                       False                     False             False
# 167116                      False                     False             False
# 70402                       False                     False             False
# 12942                       False                     False             False
# 92143                       False                     False             False
#
# [9480 rows x 143 columns]

# %%
len(X_test['area'])
# Out:
# 4064

# %%
# Plotting Actual vs. Predicted values
plt.figure(figsize=(10, 6))

# Scatter plot of actual vs. predicted values
plt.scatter(y_test, y_pred, label='Predicted vs Actual', color='blue', alpha=0.5)

# Plot a reference line for perfect predictions
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', label='Perfect Prediction')

# Adding labels and title
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.legend()

# Show the plot
plt.show()

# %%
import pickle

with open('house_price_model.pkl', 'wb') as file:
    pickle.dump(rf_regressor, file)
